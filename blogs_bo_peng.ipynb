# %% [markdown]
# *Last updated in 01/2020 since 12/2019*
# # Bo's Research Blogs

# %% [markdown]
# ### [Anomaly Detection](#ad) | [Image Segmentation](#img_seg)  | [Object Detection](#obj_detect)  | [Image Classification](#img_classification) | [Others](#others)

# %% [markdown]
# ### <a id="ad" style="color:#3b3b3b;">Anomaly Detection</a>
#
# <a style="text-decoration:none" href="blogs/review_ocgan.html">[Review] OCGAN: One-class Novelty Detection Using GANs with Constrained Latent Representations</a>

# %% [markdown]
# ### <a id="ad" style="color:#3b3b3b;">Others</a>
#
# <a style="text-decoration:none" href="blogs/review_show_and_tell.html">[Review] Show and Tell: A Neural Image Caption Generator</a><br>
# <a style="text-decoration:none" href="blogs/online_image_set_stats.html">Online Computation of Mean and Standard Deviation of an Image Set in Machine Learning</a>
