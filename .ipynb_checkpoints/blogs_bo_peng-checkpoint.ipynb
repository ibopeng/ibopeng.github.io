# %% [markdown]
# *Last updated in 01/2020 since 12/2019*
# # Bo's Research Blogs on Machine Learning and Computer Vision

# %% [markdown]
# ### [Machine Learning & Deep Learning](#ml) | [Computer Vision & Image Processing](#cv)  | [Others](#others)

# %% [markdown]
# ### <a id="ml" style="color:#3b3b3b;">Machine Learning & Deep Learning</a>
# <a style="text-decoration:none" href="blogs/online_image_set_stats.html">Online Computation of Mean and Standard Deviation of an Image Set in Machine Learning</a> <br>
# <a style="text-decoration:none" href="blogs/review_ocgan.html">[Review] OCGAN: One-class Novelty Detection Using GANs with Constrained Latent Representations</a>

# %% [markdown]
# ### <a id="cv" style="color:#3b3b3b;">Computer Vision & Image Processing</a>
#
# <a style="text-decoration:none" href="blogs/review_show_and_tell.html">[Review] Show and Tell: A Neural Image Caption Generator</a><br>
